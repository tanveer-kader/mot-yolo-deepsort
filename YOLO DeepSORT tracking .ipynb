# %%
# !pip install deep-sort-realtime
# !pip install ultralytics
# !pip install datetime

# %%
import datetime  # Library for handling date and time operations
from ultralytics import YOLO  # Library for loading and using the YOLO model
import cv2  # OpenCV library for image and video processing
from deep_sort_realtime.deepsort_tracker import DeepSort  # Library for the DeepSORT tracker
#from google.colab.patches import cv2_imshow  # Library for displaying images in Google Colab

def create_video_writer(video_cap, output_filename):
    # Function to create a video writer object for saving the output video
    frame_width = int(video_cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    frame_height = int(video_cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps = int(video_cap.get(cv2.CAP_PROP_FPS))
    fourcc = cv2.VideoWriter_fourcc(*'MP4V')
    writer = cv2.VideoWriter(output_filename, fourcc, fps, (frame_width, frame_height))
    return writer

CONFIDENCE_THRESHOLD = 0.8  # Confidence threshold for detecting objects
GREEN = (0, 255, 0)  # Color for drawing bounding boxes
WHITE = (255, 255, 255)  # Color for drawing text

video_cap = cv2.VideoCapture("input_human.mp4")  # Initialize the video capture object to read the video
writer = create_video_writer(video_cap, "output_human.mp4")  # Initialize the video writer object to save the processed video

model = YOLO("yolov8n.pt")  # Load the pre-trained YOLOv8n model
tracker = DeepSort(max_age=50)  # Initialize the DeepSORT tracker

while True:
    start = datetime.datetime.now()  # Record the start time

    ret, frame = video_cap.read()  # Read a frame from the video
    if not ret:
        break  # Exit the loop if no frame is read

    detections = model(frame)[0]  # Run the YOLO model on the frame to detect objects
    results = []

    for data in detections.boxes.data.tolist():
        confidence = data[4]  # Extract the confidence level of the detection
        if float(confidence) < CONFIDENCE_THRESHOLD:
            continue  # Ignore detections with low confidence

        # Get the bounding box coordinates and class ID
        xmin, ymin, xmax, ymax = int(data[0]), int(data[1]), int(data[2]), int(data[3])
        class_id = int(data[5])
        results.append([[xmin, ymin, xmax - xmin, ymax - ymin], confidence, class_id])

    tracks = tracker.update_tracks(results, frame=frame)
    for track in tracks:
        if not track.is_confirmed():
            continue  # Ignore unconfirmed tracks

        track_id = track.track_id  # Get the track ID
        ltrb = track.to_ltrb()  # Get the bounding box coordinates
        xmin, ymin, xmax, ymax = int(ltrb[0]), int(ltrb[1]), int(ltrb[2]), int(ltrb[3])

        # Draw the bounding box and the track ID on the frame
        cv2.rectangle(frame, (xmin, ymin), (xmax, ymax), GREEN, 2)
        cv2.rectangle(frame, (xmin, ymin - 20), (xmin + 20, ymin), GREEN, -1)
        cv2.putText(frame, str(track_id), (xmin + 5, ymin - 8), cv2.FONT_HERSHEY_SIMPLEX, 0.5, WHITE, 2)

    end = datetime.datetime.now()  # Record the end time
    print(f"Time to process 1 frame: {(end - start).total_seconds() * 1000:.0f} milliseconds")
    fps = f"FPS: {1 / (end - start).total_seconds():.2f}"  # Calculate and display the FPS
    cv2.putText(frame, fps, (50, 50), cv2.FONT_HERSHEY_SIMPLEX, 2, (0, 0, 255), 8)

    # Display the frame and write it to the output video
    #cv2.imshow(frame)
    writer.write(frame)

    #if cv2.waitKey(1) == ord("q"):
        #break  # Exit the loop if 'q' key is pressed

video_cap.release()  # Release the video capture object
writer.release()  # Release the video writer object
#cv2.destroyAllWindows()  # Close all OpenCV windows
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8n.pt to 'yolov8n.pt'...
# 100%|█████████████████████████████████████████████████████████████████████████████| 6.25M/6.25M [00:01<00:00, 3.92MB/s]
# 0: 384x640 1 person, 15 cars, 1 bus, 1 truck, 247.2ms
# Speed: 10.6ms preprocess, 247.2ms inference, 28.8ms postprocess per image at shape (1, 3, 384, 640)
# Time to process 1 frame: 1065 milliseconds
#
# 0: 384x640 1 person, 15 cars, 1 bus, 1 truck, 129.5ms
# Speed: 8.0ms preprocess, 129.5ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# Time to process 1 frame: 594 milliseconds
#
# 0: 384x640 1 person, 15 cars, 1 bus, 2 trucks, 137.5ms
# Speed: 6.0ms preprocess, 137.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Time to process 1 frame: 394 milliseconds
#
# 0: 384x640 1 person, 15 cars, 1 bus, 2 trucks, 132.7ms
# Speed: 4.0ms preprocess, 132.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Time to process 1 frame: 463 milliseconds
#
# 0: 384x640 1 person, 15 cars, 1 bus, 2 trucks, 129.0ms
# Speed: 5.9ms preprocess, 129.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Time to process 1 frame: 423 milliseconds
#
# 0: 384x640 1 person, 14 cars, 1 bus, 2 trucks, 130.6ms
# Speed: 4.0ms preprocess, 130.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Time to process 1 frame: 396 milliseconds
#
# 0: 384x640 1 person, 14 cars, 1 bus, 2 trucks, 133.3ms
# Speed: 5.0ms preprocess, 133.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Time to process 1 frame: 391 milliseconds
#
# 0: 384x640 1 person, 14 cars, 1 bus, 2 trucks, 132.8ms
# Speed: 3.0ms preprocess, 132.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Time to process 1 frame: 391 milliseconds
#
# 0: 384x640 1 person, 14 cars, 2 trucks, 130.7ms
# Speed: 4.0ms preprocess, 130.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Time to process 1 frame: 335 milliseconds
#
# 0: 384x640 14 cars, 1 bus, 1 truck, 167.7ms
# Speed: 11.1ms preprocess, 167.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Time to process 1 frame: 467 milliseconds
#
# 0: 384x640 1 person, 14 cars, 1 bus, 1 truck, 153.7ms
# Speed: 4.0ms preprocess, 153.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Time to process 1 frame: 395 milliseconds
#
# 0: 384x640 1 person, 12 cars, 1 bus, 2 trucks, 135.4ms
# Speed: 5.6ms preprocess, 135.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Time to process 1 frame: 349 milliseconds
#
# 0: 384x640 1 person, 12 cars, 2 trucks, 131.0ms
# Speed: 6.0ms preprocess, 131.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Time to process 1 frame: 364 milliseconds
#
# 0: 384x640 1 person, 12 cars, 2 trucks, 130.1ms
# Speed: 4.0ms preprocess, 130.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Time to process 1 frame: 421 milliseconds
#
# 0: 384x640 1 person, 13 cars, 1 bus, 2 trucks, 152.1ms
# Speed: 4.0ms preprocess, 152.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Time to process 1 frame: 435 milliseconds
#
# 0: 384x640 1 person, 13 cars, 2 trucks, 141.8ms
# Speed: 4.0ms preprocess, 141.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Time to process 1 frame: 398 milliseconds
#
# 0: 384x640 1 person, 13 cars, 2 trucks, 148.8ms
# Speed: 6.0ms preprocess, 148.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Time to process 1 frame: 349 milliseconds
#
# 0: 384x640 1 person, 14 cars, 1 bus, 2 trucks, 1 parking meter, 177.3ms
# Speed: 4.0ms preprocess, 177.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Time to process 1 frame: 379 milliseconds
#
# 0: 384x640 1 person, 13 cars, 1 bus, 2 trucks, 141.3ms
# Speed: 4.0ms preprocess, 141.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Time to process 1 frame: 373 milliseconds
#
# 0: 384x640 1 person, 13 cars, 1 bus, 2 trucks, 137.3ms
# Speed: 4.0ms preprocess, 137.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Time to process 1 frame: 374 milliseconds
#
# 0: 384x640 1 person, 12 cars, 3 trucks, 141.5ms
# Speed: 7.3ms preprocess, 141.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Time to process 1 frame: 920 milliseconds
#
# 0: 384x640 1 person, 14 cars, 2 trucks, 214.0ms
# Speed: 5.1ms preprocess, 214.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Time to process 1 frame: 459 milliseconds
#
# 0: 384x640 13 cars, 2 trucks, 134.6ms
# Speed: 4.0ms preprocess, 134.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Time to process 1 frame: 377 milliseconds
#
# 0: 384x640 1 person, 12 cars, 2 trucks, 131.4ms
# Speed: 3.2ms preprocess, 131.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Time to process 1 frame: 449 milliseconds
#
# 0: 384x640 1 person, 12 cars, 2 trucks, 127.2ms
# Speed: 4.0ms preprocess, 127.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Time to process 1 frame: 371 milliseconds
#
# 0: 384x640 12 cars, 1 bus, 2 trucks, 164.9ms
# Speed: 8.0ms preprocess, 164.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Time to process 1 frame:
milliseconds
#
# 0: 384x640 14 cars, 1 bus, 146.6ms
# Speed: 0.0ms preprocess, 146.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Time to process 1 frame: 481 milliseconds
#
# 0: 384x640 15 cars, 1 bus, 1 truck, 117.2ms
# Speed: 4.0ms preprocess, 117.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Time to process 1 frame: 400 milliseconds
#
# 0: 384x640 14 cars, 1 bus, 125.0ms
# Speed: 0.0ms preprocess, 125.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Time to process 1 frame: 459 milliseconds
#
# 0: 384x640 15 cars, 1 bus, 109.4ms
# Speed: 0.0ms preprocess, 109.4ms inference, 15.6ms postprocess per image at shape (1, 3, 384, 640)
# Time to process 1 frame: 598 milliseconds
#
# 0: 384x640 15 cars, 1 bus, 1 truck, 122.5ms
# Speed: 4.0ms preprocess, 122.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Time to process 1 frame: 543 milliseconds
#
# 0: 384x640 15 cars, 1 bus, 1 truck, 124.7ms
# Speed: 15.6ms preprocess, 124.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Time to process 1 frame: 515 milliseconds
#
# 0: 384x640 15 cars, 1 bus, 1 truck, 124.9ms
# Speed: 15.6ms preprocess, 124.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Time to process 1 frame: 550 milliseconds
#
# 0: 384x640 15 cars, 1 truck, 127.1ms
# Speed: 0.0ms preprocess, 127.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Time to process 1 frame: 527 milliseconds
#
# 0: 384x640 15 cars, 1 bus, 1 truck, 143.7ms
# Speed: 0.0ms preprocess, 143.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Time to process 1 frame: 463 milliseconds
#
# 0: 384x640 15 cars, 1 bus, 125.0ms
# Speed: 15.6ms preprocess, 125.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Time to process 1 frame: 455 milliseconds
#
# 0: 384x640 15 cars, 1 bus, 125.0ms
# Speed: 0.0ms preprocess, 125.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Time to process 1 frame: 552 milliseconds
#
# 0: 384x640 16 cars, 1 bus, 125.0ms
# Speed: 0.0ms preprocess, 125.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Time to process 1 frame: 473 milliseconds
#
# 0: 384x640 15 cars, 1 bus, 125.0ms
# Speed: 0.0ms preprocess, 125.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Time to process 1 frame: 426 milliseconds
#
# 0: 384x640 16 cars, 1 bus, 125.0ms
# Speed: 0.0ms preprocess, 125.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Time to process 1 frame: 524 milliseconds
#
# 0: 384x640 15 cars, 1 bus, 1 truck, 130.2ms
# Speed: 0.0ms preprocess, 130.2ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# Time to process 1 frame: 530 milliseconds
#
# 0: 384x640 15 cars, 1 bus, 125.0ms
# Speed: 0.0ms preprocess, 125.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Time to process 1 frame: 471 milliseconds
#
# 0: 384x640 15 cars, 1 bus, 109.5ms
# Speed: 6.5ms preprocess, 109.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Time to process 1 frame: 504 milliseconds
#
# 0: 384x640 15 cars, 1 bus, 125.0ms
# Speed: 0.0ms preprocess, 125.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Time to process 1 frame: 565 milliseconds
#
# 0: 384x640 15 cars, 1 bus, 1 truck, 109.4ms
# Speed: 0.0ms preprocess, 109.4ms inference, 15.6ms postprocess per image at shape (1, 3, 384, 640)
# Time to process 1 frame: 549 milliseconds
#
# 0: 384x640 15 cars, 1 bus, 1 truck, 125.0ms
# Speed: 0.0ms preprocess, 125.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Time to process 1 frame: 484 milliseconds
#
# 0: 384x640 16 cars, 1 truck, 138.5ms
# Speed: 0.0ms preprocess, 138.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Time to process 1 frame: 452 milliseconds
#
# 0: 384x640 16 cars, 1 truck, 115.7ms
# Speed: 2.1ms preprocess, 115.7ms inference, 15.6ms postprocess per image at shape (1, 3, 384, 640)
# Time to process 1 frame: 421 milliseconds
#
# 0: 384x640 15 cars, 1 bus, 125.0ms
# Speed: 0.0ms preprocess, 125.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Time to process 1 frame: 432 milliseconds
#
# 0: 384x640 15 cars, 1 bus, 1 truck, 109.4ms
# Speed: 0.0ms preprocess, 109.4ms inference, 15.6ms postprocess per image at shape (1, 3, 384, 640)
# Time to process 1 frame: 459 milliseconds
#
# 0: 384x640 14 cars, 1 bus, 2 trucks, 112.5ms
# Speed: 4.0ms preprocess, 112.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Time to process 1 frame: 468 milliseconds
#
# 0: 384x640 14 cars, 1 bus, 125.0ms
# Speed: 0.0ms preprocess, 125.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Time to process 1 frame: 439 milliseconds
#
# 0: 384x640 13 cars, 1 bus, 1 truck, 124.9ms
# Speed: 0.0ms preprocess, 124.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Time to process 1 frame: 375 milliseconds
#
# 0: 384x640 13 cars, 1 bus, 1 truck, 137.7ms
# Speed: 0.0ms preprocess, 137.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Time to process 1 frame: 387 milliseconds
#
# 0: 384x640 13 cars, 1 bus, 109.4ms
# Speed: 15.6ms preprocess, 109.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Time to process 1 frame: 430 milliseconds
#
# 0: 384x640 13 cars, 1 bus, 136.4ms
# Speed: 0.0ms preprocess, 136.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Time to process 1 frame: 449 milliseconds
#
# 0: 384x640 13 cars, 1 bus, 109.4ms
# Speed: 15.6ms preprocess, 109.4ms inference, 15.6ms postprocess per image at shape (1, 3, 384, 640)
# Time to process 1 frame: 440 milliseconds
#
# 0: 384x640 12 cars, 1 bus, 125.0ms
# Speed: 0.0ms preprocess, 125.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Time to process 1 frame: 471 milliseconds
#
# 0: 384x640 12 cars, 1 bus, 125.0ms
# Speed: 0.0ms preprocess, 125.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Time to process 1 frame: 505 milliseconds
#
# 0: 384x640 12 cars, 1 bus, 169.6ms
# Speed: 0.0ms preprocess, 169.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Time to process 1 frame: 633 milliseconds
#
# 0: 384x640 12 cars, 1 bus, 157.3ms
# Speed: 15.6ms preprocess, 157.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Time to process 1 frame: 590 milliseconds
#
# 0: 384x640 12 cars, 1 bus, 152.5ms
# Speed: 0.0ms preprocess, 152.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Time to process 1 frame: 533 milliseconds
#
# 0: 384x640 12 cars, 1 bus, 127.1ms
# Speed: 4.0ms preprocess, 127.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Time to process 1 frame: 491 milliseconds
#
# 0: 384x640 12 cars, 1 bus, 121.3ms
# Speed: 4.5ms preprocess, 121.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Time to process 1 frame: 437 milliseconds
#
# 0: 384x640 12 cars, 1 bus, 127.7ms
# Speed: 0.0ms preprocess, 127.7ms inference, 13.1ms postprocess per image at shape (1, 3, 384, 640)
# Time to process 1 frame: 467 milliseconds
# 0: 384x640 12 cars, 1 bus, 125.8ms
# Speed: 15.6ms preprocess, 125.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Time to process 1 frame: 371 milliseconds
#
# 0: 384x640 12 cars, 1 bus, 1 truck, 109.4ms
# Speed: 15.6ms preprocess, 109.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Time to process 1 frame: 406 milliseconds
#
# 0: 384x640 12 cars, 1 bus, 107.8ms
# Speed: 3.0ms preprocess, 107.8ms inference, 15.6ms postprocess per image at shape (1, 3, 384, 640)
# Time to process 1 frame: 424 milliseconds
#
# 0: 384x640 13 cars, 1 bus, 110.4ms
# Speed: 15.6ms preprocess, 110.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Time to process 1 frame: 423 milliseconds
#
# 0: 384x640 13 cars, 1 bus, 125.0ms
# Speed: 0.0ms preprocess, 125.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Time to process 1 frame: 424 milliseconds
#
# 0: 384x640 12 cars, 1 bus, 109.4ms
# Speed: 0.0ms preprocess, 109.4ms inference, 15.6ms postprocess per image at shape (1, 3, 384, 640)
# Time to process 1 frame: 456 milliseconds
#
# 0: 384x640 12 cars, 1 bus, 125.0ms
# Speed: 0.0ms preprocess, 125.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Time to process 1 frame: 455 milliseconds
#
# 0: 384x640 12 cars, 1 bus, 1 truck, 210.5ms
# Speed: 15.6ms preprocess, 210.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Time to process 1 frame: 708 milliseconds
#
# 0: 384x640 12 cars, 1 truck, 144.2ms
# Speed: 17.0ms preprocess, 144.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Time to process 1 frame: 458 milliseconds
#
# 0: 384x640 12 cars, 1 truck, 165.6ms
# Speed: 0.0ms preprocess, 165.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Time to process 1 frame: 424 milliseconds
#
# 0: 384x640 12 cars, 1 bus, 1 truck, 109.4ms
# Speed: 0.0ms preprocess, 109.4ms inference, 15.6ms postprocess per image at shape (1, 3, 384, 640)
# Time to process 1 frame: 428 milliseconds
#
# 0: 384x640 12 cars, 1 bus, 1 truck, 133.4ms
# Speed: 5.1ms preprocess, 133.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Time to process 1 frame: 391 milliseconds
#
# 0: 384x640 12 cars, 1 bus, 1 truck, 136.8ms
# Speed: 15.6ms preprocess, 136.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Time to process 1 frame: 392 milliseconds
#
# 0: 384x640 12 cars, 1 bus, 162.2ms
# Speed: 0.0ms preprocess, 162.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Time to process 1 frame: 427 milliseconds
#
# 0: 384x640 12 cars, 1 bus, 122.3ms
# Speed: 0.0ms preprocess, 122.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Time to process 1 frame: 392 milliseconds
#
# 0: 384x640 12 cars, 1 bus, 132.3ms
# Speed: 4.5ms preprocess, 132.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Time to process 1 frame: 391 milliseconds
#
# 0: 384x640 12 cars, 1 bus, 137.5ms
# Speed: 0.0ms preprocess, 137.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Time to process 1 frame: 408 milliseconds
#
# 0: 384x640 11 cars, 1 bus, 118.4ms
# Speed: 15.5ms preprocess, 118.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Time to process 1 frame: 394 milliseconds
#
# 0: 384x640 11 cars, 1 bus, 165.7ms
# Speed: 4.0ms preprocess, 165.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Time to process 1 frame: 526 milliseconds
#
# 0: 384x640 11 cars, 1 bus, 134.3ms
# Speed: 4.0ms preprocess, 134.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Time to process 1 frame: 357 milliseconds
#
# 0: 384x640 11 cars, 1 bus, 125.0ms
# Speed: 0.0ms preprocess, 125.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Time to process 1 frame: 387 milliseconds
#
# 0: 384x640 11 cars, 1 bus, 125.0ms
# Speed: 0.0ms preprocess, 125.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Time to process 1 frame: 423 milliseconds
#
# 0: 384x640 11 cars, 1 bus, 109.4ms
# Speed: 0.0ms preprocess, 109.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Time to process 1 frame: 409 milliseconds
#
# 0: 384x640 11 cars, 1 bus, 117.8ms
# Speed: 0.0ms preprocess, 117.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Time to process 1 frame: 386 milliseconds
#
# 0: 384x640 11 cars, 1 bus, 138.1ms
# Speed: 0.0ms preprocess, 138.1ms inference, 15.5ms postprocess per image at shape (1, 3, 384, 640)
# Time to process 1 frame: 470 milliseconds
#
# 0: 384x640 11 cars, 1 bus, 99.8ms
# Speed: 3.0ms preprocess, 99.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Time to process 1 frame: 383 milliseconds
#
# 0: 384x640 11 cars, 1 bus, 132.9ms
# Speed: 0.0ms preprocess, 132.9ms inference, 15.6ms postprocess per image at shape (1, 3, 384, 640)
# Time to process 1 frame: 420 milliseconds
#
# 0: 384x640 11 cars, 1 bus, 126.7ms
# Speed: 0.0ms preprocess, 126.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Time to process 1 frame: 380 milliseconds
#
# 0: 384x640 11 cars, 1 bus, 109.4ms
# Speed: 0.0ms preprocess, 109.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
